# %%
import os
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

# %%
# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/calendar']

# %%
creds = None

# %%
# The file token.json stores the user's access and refresh tokens.
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)

# %%
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file("credentials.json", SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=966637880266-53gp75hefg9n9ip73t87ql64qujvnerh.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A59178%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar&state=PQKIV7tu4nRucnaTQVgt0lwBRJ1BXh&code_challenge=fZCsNXO_MiyBCVYZ53ClWI6ldeouTghj6rkqvwLyGLw&code_challenge_method=S256&access_type=offline

# %%
def get_calendar_service():
    """Authenticates the user and returns the Calendar API service object."""
    creds = None
    # The file token.json stores the user's access and refresh tokens.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
        
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    return build('calendar', 'v3', credentials=creds)

# %%
get_calendar_service()
